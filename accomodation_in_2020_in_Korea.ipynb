# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rc('axes', unicode_minus=False)
plt.rc('font', family='NanumGothic')

df = pd.read_csv('C:\\Users\\hhshi\\OneDrive\\바탕 화면\\Data_Science\\부스트캠프 데이터프로젝트_21년8월\\2020_accomodation.csv',encoding = 'utf-8')
df
# Out:
#         번호 지역1(시도) 지역2(시군구)        업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0        1      강원      춘천시      관광호텔      춘천세종관광호텔            주식회사 세종
# 1        2      강원      춘천시      관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠
# 2        3      강원      원주시      관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주
# 3        4      강원      원주시      관광호텔      베니키아문막호텔            주식회사 해평
# 4        5      강원      원주시      관광호텔         호텔비즈인            주식회사 청연
# ...    ...     ...      ...       ...           ...                ...
# 2296  2297    경상북도      영덕군  휴양콘도미니엄업  오션비치 휴양콘도미니엄              ㈜오션비치
# 2297  2298    경상북도      울진군  휴양콘도미니엄업     한화호텔&리조트㈜                 문석
# 2298  2299    경상북도      울진군  휴양콘도미니엄업        덕구온천콘도                강윤석
# 2299  2300   인천광역시       중구  휴양콘도미니엄업      THEWEEK&                휴업중
# 2300  2301   인천광역시      옹진군  휴양콘도미니엄업         마린프라자                휴업중
#
#      영업상태(19.12.31기준)                             주소(도로명주소)
# ...

# %%
df = df.dropna()
df
# Out:
#         번호 지역1(시도) 지역2(시군구)        업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0        1      강원      춘천시      관광호텔      춘천세종관광호텔            주식회사 세종
# 1        2      강원      춘천시      관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠
# 2        3      강원      원주시      관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주
# 3        4      강원      원주시      관광호텔      베니키아문막호텔            주식회사 해평
# 4        5      강원      원주시      관광호텔         호텔비즈인            주식회사 청연
# ...    ...     ...      ...       ...           ...                ...
# 2295  2296    경상북도      청송군  휴양콘도미니엄업         소노벨청송           소노호텔앤리조트
# 2296  2297    경상북도      영덕군  휴양콘도미니엄업  오션비치 휴양콘도미니엄              ㈜오션비치
# 2297  2298    경상북도      울진군  휴양콘도미니엄업     한화호텔&리조트㈜                 문석
# 2298  2299    경상북도      울진군  휴양콘도미니엄업        덕구온천콘도                강윤석
# 2299  2300   인천광역시       중구  휴양콘도미니엄업      THEWEEK&                휴업중
#
#      영업상태(19.12.31기준)                             주소(도로명주소)
# ...

# %%
df= df.drop(2299)
df = df.drop(['번호'],axis=1)
df
# Out:
#      지역1(시도) 지역2(시군구)        업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0         강원      춘천시      관광호텔      춘천세종관광호텔            주식회사 세종
# 1         강원      춘천시      관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠
# 2         강원      원주시      관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주
# 3         강원      원주시      관광호텔      베니키아문막호텔            주식회사 해평
# 4         강원      원주시      관광호텔         호텔비즈인            주식회사 청연
# ...      ...      ...       ...           ...                ...
# 2294    경상북도      문경시  휴양콘도미니엄업       문경새재리조트                이문영
# 2295    경상북도      청송군  휴양콘도미니엄업         소노벨청송           소노호텔앤리조트
# 2296    경상북도      영덕군  휴양콘도미니엄업  오션비치 휴양콘도미니엄              ㈜오션비치
# 2297    경상북도      울진군  휴양콘도미니엄업     한화호텔&리조트㈜                 문석
# 2298    경상북도      울진군  휴양콘도미니엄업        덕구온천콘도                강윤석
#
#      영업상태(19.12.31기준)                             주소(도로명주소)
# 0                 영업중                          춘천시 봉의동 15-3
# 1                 영업중                         춘천시 삼천동 300-3
# ...

# %%
gr = df[(df['지역1(시도)']=='강원')&(df['지역2(시군구)']=='강릉시')]
gr
# Out:
#    지역1(시도) 지역2(시군구)     업종                       호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 7       강원      강릉시   관광호텔                           씨마크호텔           권오갑, 가삼현
# 8       강원      강릉시   관광호텔                          경포비치호텔                박상수
# 9       강원      강릉시   관광호텔  HONG C HOTEL Gangneung Station                홍종표
# 10      강원      강릉시   관광호텔                          강릉관광호텔                김운성
# 11      강원      강릉시   관광호텔                    Hotel Tops10          김종민,\n고용재
# 12      강원      강릉시   관광호텔      THE HONG C HOTEL Gangneung                홍종표
# 13      강원      강릉시   관광호텔                         호텔이스트나인                최혁진
# 45      강원      강릉시   가족호텔                          주문진리조트                음덕성
# 46      강원      강릉시   가족호텔                      썬크루즈호텔&리조트                박기열
# 62      강원      강릉시    호스텔                       게스트하우스 안도           조우석, 이지연
# 63      강원      강릉시    호스텔                           썬앤제이드                최규옥
# ...

# %%
df = df[df['영업상태(19.12.31기준)']=='영업중']
df
# Out:
#      지역1(시도) 지역2(시군구)        업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0         강원      춘천시      관광호텔      춘천세종관광호텔            주식회사 세종
# 1         강원      춘천시      관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠
# 2         강원      원주시      관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주
# 4         강원      원주시      관광호텔         호텔비즈인            주식회사 청연
# 5         강원      원주시      관광호텔        ㈜오키드호텔          주식회사오키드호텔
# ...      ...      ...       ...           ...                ...
# 2294    경상북도      문경시  휴양콘도미니엄업       문경새재리조트                이문영
# 2295    경상북도      청송군  휴양콘도미니엄업         소노벨청송           소노호텔앤리조트
# 2296    경상북도      영덕군  휴양콘도미니엄업  오션비치 휴양콘도미니엄              ㈜오션비치
# 2297    경상북도      울진군  휴양콘도미니엄업     한화호텔&리조트㈜                 문석
# 2298    경상북도      울진군  휴양콘도미니엄업        덕구온천콘도                강윤석
#
#      영업상태(19.12.31기준)                             주소(도로명주소)
# 0                 영업중                          춘천시 봉의동 15-3
# 1                 영업중                         춘천시 삼천동 300-3
# ...

# %%
jeonnam = df[df['지역1(시도)']=='전남'].copy()
print(len(jeonnam))
jeonnam
# Out:
# 292
#      지역1(시도) 지역2(시군구)       업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 1932      전남      목포시     관광호텔      신안비치호텔                우경선
# 1933      전남      목포시     관광호텔   ㈜샹그리아비치호텔                조길현
# 1934      전남      목포시     관광호텔  ㈜폰타나비치관광호텔                박은석
# 1935      전남      목포시     관광호텔       호텔몬다비                윤영문
# 1936      전남      목포시     관광호텔    비즈니스호텔가빈                황인석
# ...      ...      ...      ...         ...                ...
# 2227      전남      완도군     가족호텔   완도해조류스파랜드       주식회사\n국민레저산업
# 2229      전남      완도군     가족호텔  완도퍼핀스베이리조트         주식회사 굿투어비스
# 2230      전남      완도군      호스텔    완도대교 호스텔                이용혁
# 2231      전남      진도군  휴양콘도미니엄  쏠비치 리조트 진도                최주영
# 2232      전남      진도군     관광호텔   쏠비치 호텔 진도                최주영
#
#      영업상태(19.12.31기준)                주소(도로명주소)
# 1932              영업중        전남 목포시 해안로 2(죽교동)
# 1933              영업중         전남 목포시 평화로79(상동)
# 1934              영업중        전남 목포시 평화로 69(상동)
# ...

# %%
jeonbuk = df[df['지역1(시도)']=='전북'].copy()
print(len(jeonbuk))
jeonbuk
# Out:
# 45
#      지역1(시도) 지역2(시군구)       업종             호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2236      전북      전주시    관광호텔업                  호텔한성                김이재
# 2237      전북      전주시    관광호텔업               화이트관광호텔                김정식
# 2238      전북      전주시    관광호텔업           째즈어라운드 관광호텔    ㈜디앤비째쯔어라운드(양해은)
# 2239      전북      전주시    관광호텔업                풍남관광호텔           왕영식, 김신옥
# 2240      전북      전주시    관광호텔업                전주관광호텔                박범도
# 2241      전북      전주시    관광호텔업                전주영화호텔                송중숙
# 2242      전북      전주시    관광호텔업                로니관광호텔         (유)조목(이재청)
# 2243      전북      전주시    관광호텔업                JS관광호텔                조종술
# 2244      전북      전주시    관광호텔업                엔브릿지호텔       ㈜성원엔브릿지(최성필)
# 2245      전북      전주시    관광호텔업              그랜드힐스턴호텔      ㈜케이원관광개발(김금석)
# 2246      전북      전주시    관광호텔업               호텔오페라21                박성일
# 2247      전북      전주시    관광호텔업                 더메이호텔         ㈜엔씨아이(김성률)
# ...

# %%
jeonbuk['지역2(시군구)'].value_counts()
# Out:
# 전주시    21
# 군산시     8
# 무주군     7
# 남원시     6
# 익산시     2
# 정읍시     1
# Name: 지역2(시군구), dtype: int64

# %%
jeonju = jeonbuk[jeonbuk['지역2(시군구)']=='전주시'].copy()
jeonju
# Out:
#      지역1(시도) 지역2(시군구)       업종      호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2236      전북      전주시    관광호텔업           호텔한성                김이재
# 2237      전북      전주시    관광호텔업        화이트관광호텔                김정식
# 2238      전북      전주시    관광호텔업    째즈어라운드 관광호텔    ㈜디앤비째쯔어라운드(양해은)
# 2239      전북      전주시    관광호텔업         풍남관광호텔           왕영식, 김신옥
# 2240      전북      전주시    관광호텔업         전주관광호텔                박범도
# 2241      전북      전주시    관광호텔업         전주영화호텔                송중숙
# 2242      전북      전주시    관광호텔업         로니관광호텔         (유)조목(이재청)
# 2243      전북      전주시    관광호텔업         JS관광호텔                조종술
# 2244      전북      전주시    관광호텔업         엔브릿지호텔       ㈜성원엔브릿지(최성필)
# 2245      전북      전주시    관광호텔업       그랜드힐스턴호텔      ㈜케이원관광개발(김금석)
# 2246      전북      전주시    관광호텔업        호텔오페라21                박성일
# 2247      전북      전주시    관광호텔업          더메이호텔         ㈜엔씨아이(김성률)
# 2248      전북      전주시  한국전통호텔업       나비잠 한옥호텔        나비네트웍스 주식회사
# ...

# %%
gunsan = jeonbuk[jeonbuk['지역2(시군구)']=='군산시'].copy()
gunsan
# Out:
#      지역1(시도) 지역2(시군구)     업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2257      전북      군산시  관광호텔업       리츠프라자호텔                고기점
# 2258      전북      군산시  관광호텔업  유한회사 베니키아아리울                 박승
# 2259      전북      군산시  관광호텔업   베스트웨스턴 군산호텔                정원석
# 2260      전북      군산시  관광호텔업      오스카 관광호텔                주영미
# 2262      전북      군산시  관광호텔업    군산리버힐 관광호텔                최종두
# 2263      전북      군산시  관광호텔업       라마다호텔군산                이성일
# 2264      전북      군산시  관광호텔업      제이앤케이 호텔                권채영
# 2265      전북      군산시  관광호텔업     호텔 은파 팰리스                정호경
#
#      영업상태(19.12.31기준)             주소(도로명주소)
# 2257              영업중   전북 군산시 한밭안길 30(나운동)
# 2258              영업중  전북 군산시 가도안1길45(오식도동)
# 2259              영업중       전북 군산시 새만금북로435
# 2260              영업중    전북 군산시 소룡1길55(소룡동)
# 2262              영업중     전북 군산시 성산면 철새로 56
# 2263              영업중    전북 군산시 대학로400(나운동)
# 2264              영업중         전북 군산시 부원로 24
# 2265              영업중       전북 군산시 은파순환길 20

# %%
muju = jeonbuk[jeonbuk['지역2(시군구)']=='무주군'].copy()
muju
# Out:
#      지역1(시도) 지역2(시군구)      업종      호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2277      전북      무주군   관광호텔업  ㈜무주덕유산리조트티롤호텔           김병철, 최양환
# 2278      전북      무주군   가족호텔업      ㈜무주덕유산리조트           김병철, 최양환
# 2279      전북      무주군   가족호텔업       무주글램펜션힐스                서동해
# 2280      전북      무주군    호스텔업    무주해바라기펜션호스텔                김선욱
# 2281      전북      무주군   가족호텔업     나봄리조트 주식회사                서호진
# 2282      전북      무주군  콘도미니엄업      일성무주콘도미니엄                이규표
# 2283      전북      무주군  콘도미니엄업        ㈜토비스알앤씨                이희창
#
#      영업상태(19.12.31기준)                주소(도로명주소)
# 2277              영업중       전북 무주군 설천면 만선로 185
# 2278              영업중       전북 무주군 설천면 만선로 185
# 2279              영업중      전북 무주군 설천면 구천동1로 30
# 2280              영업중  전북 무주군 설천면 구천동1로 129-15
# 2281              영업중        전북 무주군 설천면 월곡길 45
# 2282              영업중     전북 무주군 무풍면 라제통문로 455
# 2283              영업중       전북 무주군 무풍면 삼거리 120

# %%
namwon = jeonbuk[jeonbuk['지역2(시군구)']=='남원시'].copy()
namwon
# Out:
#      지역1(시도) 지역2(시군구)      업종             호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2270      전북      남원시  콘도미니엄업  이랜드파크\n 켄싱턴리조트 지리산남원                윤성대
# 2271      전북      남원시  콘도미니엄업            지리산하이츠\n콘도                조규영
# 2272      전북      남원시  콘도미니엄업            지리산토비스\n콘도                이희창
# 2273      전북      남원시  콘도미니엄업          일성지리산\n콘도미니엄                이규표
# 2274      전북      남원시   관광호텔업        ㈜교원프라퍼티스위트호텔남원                장평순
# 2275      전북      남원시   관광호텔업            ㈜오헤브데이\n호텔                박원숙
#
#      영업상태(19.12.31기준)               주소(도로명주소)
# 2270              영업중     전북 남원시 소리길 66 (어현동)
# 2271              영업중   전북 남원시 장승안길 2-9 (산곡동)
# 2272              영업중    전북 남원시 산내면 산내원천길 4-5
# 2273              영업중  전북 남원시 산내면 천왕봉로 626-25
# 2274              영업중      전북 남원시 주천면 원천로 217
# 2275              영업중     전북 남원시 운봉읍 바래봉길 193

# %%
iksan = jeonbuk[jeonbuk['지역2(시군구)']=='익산시'].copy()
iksan
# Out:
#      지역1(시도) 지역2(시군구)     업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 2267      전북      익산시  관광호텔업  익산그랜드팰리스호텔      (주)그랜드팰리스호텔익산              영업중
# 2268      전북      익산시  관광호텔업    웨스턴라이프호텔      (유)웨스턴라이프컨소시엄              영업중
#
#                       주소(도로명주소)
# 2267        전북 익산시 목천로1길 9(평화동)
# 2268  전북 익산시 동서로 370(영등동)외 14필지

# %%
jeongeup = jeonbuk[jeonbuk['지역2(시군구)']=='정읍시'].copy()
jeongeup
# Out:
#      지역1(시도) 지역2(시군구)     업종 호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 2269      전북      정읍시  소형호텔업      호텔로얄              ㈜호텔로얄              영업중
#
#                 주소(도로명주소)
# 2269  전북 정읍시 중앙로 170(시기동)

# %%
jeonnam['지역2(시군구)'].value_counts()
# Out:
# 여수시    185
# 순천시     63
# 목포시     10
# 보성군      4
# 해남군      3
# 나주시      3
# 화순군      3
# 강진군      3
# 완도군      3
# 영암군      3
# 구례군      3
# 장흥군      2
# 장성군      2
# 고흥군      2
# 진도군      2
# 담양군      1
# Name: 지역2(시군구), dtype: int64

# %%
yeosu = jeonnam[jeonnam['지역2(시군구)']=='여수시'].copy()
yeosu
# Out:
#      지역1(시도) 지역2(시군구)       업종             호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 1942      전남      여수시     관광호텔               호텔마띠유여수                지분순
# 1943      전남      여수시     관광호텔               샹보르관광호텔                강윤기
# 1944      전남      여수시     관광호텔              비앤비치관광호텔              유송빈외1
# 1945      전남      여수시     관광호텔               나르샤관광호텔              방남석외1
# 1946      전남      여수시     관광호텔               H·S관광호텔              이영범외1
# ...      ...      ...      ...                   ...                ...
# 2123      전남      여수시      호스텔                티라 061                최명복
# 2124      전남      여수시      호스텔                 스톤하우스                김현범
# 2125      전남      여수시      호스텔                  코지호텔                강송평
# 2126      전남      여수시  휴양콘도미니엄  여수 경도 해양관광단지 휴양콘도미니엄                김철신
# 2127      전남      여수시  휴양콘도미니엄                디오션리조트                신달순
#
#      영업상태(19.12.31기준)                           주소(도로명주소)
# ...

# %%
df_real = df[~df['지역2(시군구)'].str.contains('군')]
df_real
# Out:
#      지역1(시도) 지역2(시군구)        업종          호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0         강원      춘천시      관광호텔           춘천세종관광호텔            주식회사 세종
# 1         강원      춘천시      관광호텔          춘천베어스관광호텔       유한회사 화성에이에스엠
# 2         강원      원주시      관광호텔       (주)호텔인터불고 원주        (주)호텔인터불고원주
# 4         강원      원주시      관광호텔              호텔비즈인            주식회사 청연
# 5         강원      원주시      관광호텔             ㈜오키드호텔          주식회사오키드호텔
# ...      ...      ...       ...                ...                ...
# 2290    경상북도      경주시  휴양콘도미니엄업             소노벨 경주      주식회사 소노호텔앤리조트
# 2291    경상북도      경주시  휴양콘도미니엄업      BlueOne 콘도미니엄           주식회사 블루원
# 2292    경상북도      상주시  휴양콘도미니엄업  블루원상주골프리조트휴양콘도미니엄          ㈜블루원 상주지점
# 2293    경상북도      문경시  휴양콘도미니엄업             stx리조트                김영욱
# 2294    경상북도      문경시  휴양콘도미니엄업            문경새재리조트                이문영
#
#      영업상태(19.12.31기준)              주소(도로명주소)
# 0                 영업중           춘천시 봉의동 15-3
# ...

# %%
sooncheon = jeonnam[jeonnam['지역2(시군구)']=='순천시'].copy()
sooncheon
# Out:
#      지역1(시도) 지역2(시군구)    업종       호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2129      전남      순천시  관광호텔        베네치아관광호텔                정오진
# 2130      전남      순천시  관광호텔            호텔지뜨           ㈜지앤알 김천형
# 2132      전남      순천시  관광호텔       에코그라드관광호텔          ㈜동원산업 정은집
# 2133      전남      순천시  관광호텔        파인힐스관광호텔          ㈜파인힐스 이화영
# 2134      전남      순천시  가족호텔            샤인호텔            ㈜봉화 오재대
# ...      ...      ...   ...             ...                ...
# 2189      전남      순천시   호스텔    순천만 생태 빌리지 나                조영서
# 2190      전남      순천시   호스텔    순천만 생태 빌리지 가                이성한
# 2191      전남      순천시   호스텔        순천만 풀리조트                최금숙
# 2192      전남      순천시   호스텔  순천만 ECO 빌리지 2동                소현섭
# 2193      전남      순천시   호스텔       라온하우스 호스텔                박미숙
#
#      영업상태(19.12.31기준)              주소(도로명주소)
# 2129              영업중       전라남도 순천시 팔마2길 13
# 2130              영업중       전라남도 순천시 팔마2길 13
# 2132              영업중  전라남도 순천시 백강로 234(조례동)
# ...

# %%
mokpo = jeonnam[jeonnam['지역2(시군구)']=='목포시'].copy()
mokpo
# Out:
#      지역1(시도) 지역2(시군구)    업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 1932      전남      목포시  관광호텔      신안비치호텔                우경선              영업중
# 1933      전남      목포시  관광호텔   ㈜샹그리아비치호텔                조길현              영업중
# 1934      전남      목포시  관광호텔  ㈜폰타나비치관광호텔                박은석              영업중
# 1935      전남      목포시  관광호텔       호텔몬다비                윤영문              영업중
# 1936      전남      목포시  관광호텔    비즈니스호텔가빈                황인석              영업중
# 1937      전남      목포시  가족호텔    목포가족관광호텔                강혜옥              영업중
# 1938      전남      목포시  가족호텔    유토피아가족호텔                이정숙              영업중
# 1939      전남      목포시   호스텔    JJBRO호스텔                박종문              영업중
# 1940      전남      목포시   호스텔     이코노미호스텔                김덕순              영업중
# 1941      전남      목포시   호스텔    호텔 유달호스텔                양송자              영업중
#
#                     주소(도로명주소)
# 1932        전남 목포시 해안로 2(죽교동)
# 1933         전남 목포시 평화로79(상동)
# 1934        전남 목포시 평화로 69(상동)
# ...

# %%
naju = jeonnam[jeonnam['지역2(시군구)']=='나주시'].copy()
naju
# Out:
#      지역1(시도) 지역2(시군구)       업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 2194      전남      나주시     관광호텔    홀리어스관광호텔                류정화
# 2195      전남      나주시     관광호텔        호텔코어          호텔코어 유한회사
# 2196      전남      나주시  휴양콘도미니엄  중흥골드스파&리조트             나주관광개발
#
#      영업상태(19.12.31기준)             주소(도로명주소)
# 2194              영업중        전남 나주시 배멧2길 43
# 2195              영업중     전남 나주시 배멧3길 19-13
# 2196              영업중  나주시 다도면 나주호로 588-184

# %%
gyeongbuk = df_real[df_real['지역1(시도)']=='경상북도']
gyeongbuk
# Out:
#      지역1(시도) 지역2(시군구)        업종                          호텔명(등록명칭)  \
# 175     경상북도      포항시      관광호텔                        코모도호텔 포항 송도
# 176     경상북도      포항시      관광호텔                         베니키아 호텔 포항
# 177     경상북도      포항시      관광호텔                            라한호텔 포항
# 178     경상북도      포항시      관광호텔                                윈호텔
# 179     경상북도      포항시      관광호텔                                뷰호텔
# 180     경상북도      포항시       호스텔                        동빈나루 게스트하우스
# 181     경상북도      포항시       호스텔                         영일대 게스트하우스
# 182     경상북도      포항시      소형호텔                              라우스데오
# 183     경상북도      경주시      관광호텔                              힐튼 경주
# 184     경상북도      경주시      관광호텔                          ㈜라한호텔(경주)
# 185     경상북도      경주시      관광호텔                    ㈜코오롱엘에스아이 코오롱호텔
# 186     경상북도      경주시      관광호텔                          ㈜코모도호텔 경주
# 187     경상북도      경주시      관광호텔                          The-K경주호텔
# ...

# %%
gyeongbuk['지역2(시군구)'].value_counts()
# Out:
# 경주시    23
# 포항시     9
# 안동시     8
# 문경시     3
# 구미시     2
# 영주시     2
# 경산시     1
# 상주시     1
# 김천시     1
# 영천시     1
# Name: 지역2(시군구), dtype: int64

# %%
gyeongju = gyeongbuk[gyeongbuk['지역2(시군구)']=='경주시']
gyeongju
# Out:
#      지역1(시도) 지역2(시군구)        업종         호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 183     경상북도      경주시      관광호텔             힐튼 경주       우양산업개발 주식회사
# 184     경상북도      경주시      관광호텔         ㈜라한호텔(경주)          주식회사 라한호텔
# 185     경상북도      경주시      관광호텔   ㈜코오롱엘에스아이 코오롱호텔      코오롱엘에스아이 주식회사
# 186     경상북도      경주시      관광호텔         ㈜코모도호텔 경주         주식회사 코모도호텔
# 187     경상북도      경주시      관광호텔         The-K경주호텔     더케이호텔앤리조트 주식회사
# 190     경상북도      경주시      관광호텔         스위스로젠관광호텔            주식회사 금천
# 191     경상북도      경주시      관광호텔          경주지지관광호텔          주식회사 지지옥션
# 192     경상북도      경주시      관광호텔      ㈜교원 스위트호텔 경주            주식회사 교원
# 193     경상북도      경주시      관광호텔           아리수경주호텔                김석준
# 194     경상북도      경주시      관광호텔              케이호텔                 곽희
# 195     경상북도      경주시  한국전통관광호텔        ㈜신라밀레니엄 라궁        주식회사 신라밀레니엄
# 196     경상북도      경주시       호스텔                다현                박선욱
# 197     경상북도      경주시       호스텔       청춘게스트하우스호스텔           박순희 외 2명
# ...

# %%
pohang = gyeongbuk[gyeongbuk['지역2(시군구)']=='포항시']
pohang
# Out:
#      지역1(시도) 지역2(시군구)        업종      호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 175     경상북도      포항시      관광호텔    코모도호텔 포항 송도         ㈜코모도호텔포항송도
# 176     경상북도      포항시      관광호텔     베니키아 호텔 포항         에이티홀딩스주식회사
# 177     경상북도      포항시      관광호텔        라한호텔 포항            ㈜라한호텔4호
# 178     경상북도      포항시      관광호텔            윈호텔                정기철
# 179     경상북도      포항시      관광호텔            뷰호텔                박찬욱
# 180     경상북도      포항시       호스텔    동빈나루 게스트하우스                권승철
# 181     경상북도      포항시       호스텔     영일대 게스트하우스                조영자
# 182     경상북도      포항시      소형호텔          라우스데오                 곽휘
# 2284    경상북도      포항시  휴양콘도미니엄업  오션힐스 골프 & 리조트              영우개발㈜
#
#      영업상태(19.12.31기준)               주소(도로명주소)
# 175               영업중      포항시 남구 송도로 71(송도동)
# 176               영업중     포항시 남구 중앙로 128(해도동)
# 177               영업중  포항시 북구 삼호로265번길 1(두호동)
# 178               영업중      포항시 북구 해안로 89(두호동)
# 179               영업중      포항시 북구 해안로 91(두호동)
# ...

# %%
ahndong = gyeongbuk[gyeongbuk['지역2(시군구)']=='안동시']
ahndong
# Out:
#     지역1(시도) 지역2(시군구)    업종                          호텔명(등록명칭)  \
# 204    경상북도      안동시  관광호텔                          안동 그랜드 호텔
# 205    경상북도      안동시  관광호텔                             씨엠파크호텔
# 206    경상북도      안동시  가족호텔                               리첼호텔
# 207    경상북도      안동시   호스텔  안동 호스텔 1호점(The 1st ANDONG HOSTEL)
# 208    경상북도      안동시   호스텔                           베네치아 호스텔
# 209    경상북도      안동시   호스텔                 안동풍경 호스텔 n LIBRARY
# 210    경상북도      안동시   호스텔                               더스터닝
# 211    경상북도      안동시   호스텔                              킹덤호스텔
#
#     관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)           주소(도로명주소)
# 204            주식회사 다옴              영업중  관광단지로 346-84 (성곡동)
# 205        씨엠파크호텔 주식회사              영업중       풍천면 검무로 10-17
# 206          주식회사 아르피나              영업중  관광단지로 346-69 (성곡동)
# 207                정현숙              영업중        호암길 13 (송현동)
# 208                전욱표              영업중      용상북1길 51 (용상동)
# ...

# %%
df_real['지역2(시군구)'].value_counts().head(15)
# Out:
# 중구      232
# 서귀포시    208
# 제주시     201
# 여수시     185
# 강남구      69
# 순천시      63
# 수영구      60
# 해운대구     59
# 종로구      39
# 수원시      37
# 영등포구     33
# 통영시      31
# 동구       26
# 창원시      25
# 마포구      23
# Name: 지역2(시군구), dtype: int64

# %%
df_real['지역2(시군구)'].value_counts().tail(15)
# Out:
# 상주시     1
# 김천시     1
# 광주시     1
# 서산시     1
# 영천시     1
# 영도구     1
# 금정구     1
# 경산시     1
# 미추홀구    1
# 양천구     1
# 부평구     1
# 정읍시     1
# 양주시     1
# 사상구     1
# 하남시     1
# Name: 지역2(시군구), dtype: int64

# %%
seoul_junggu = df_real[(df_real['지역1(시도)']=='서울특별시')&(df_real['지역2(시군구)']=='중구')].copy()
print("서울 중구 숙박 개수는 {}".format(len(seoul_junggu)))
seoul_junggu
# Out:
# 서울 중구 숙박 개수는 100
#     지역1(시도) 지역2(시군구)    업종            호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 765   서울특별시       중구  관광호텔                사보이호텔           (주)사보이호텔
# 766   서울특별시       중구  관광호텔                메트로호텔           (주)메트로호텔
# 767   서울특별시       중구  관광호텔              프레지던트호텔          백남관광 주식회사
# 768   서울특별시       중구  관광호텔              서울프린스호텔         (주)서울프린스호텔
# 769   서울특별시       중구  관광호텔                뉴서울호텔           (주)뉴서울호텔
# ..      ...      ...   ...                  ...                ...
# 860   서울특별시       중구   호스텔               케이스타호텔        주식회사 케이스타호텔
# 861   서울특별시       중구  관광호텔          나인트리 호텔 동대문        파르나스호텔 주식회사
# 862   서울특별시       중구  관광호텔           호텔 미드시티 명동          아시아매니징(주)
# 863   서울특별시       중구   호스텔               산마루호스텔                박한웅
# 864   서울특별시       중구  관광호텔  (주)조선호텔앤리조트 포포인츠 명동        (주)조선호텔앤리조트
#
#     영업상태(19.12.31기준)                                  주소(도로명주소)
# 765              영업중                  서울특별시 중구 명동8나길 10 (충무로1가)
# ...

# %%
incheon_junggu = df_real[(df_real['지역1(시도)']=='인천광역시')&(df_real['지역2(시군구)']=='중구')].copy()
print("인천 중구 숙박 개수는 {}".format(len(incheon_junggu)))
incheon_junggu
# Out:
# 인천 중구 숙박 개수는 111
#      지역1(시도) 지역2(시군구)    업종          호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 1224   인천광역시       중구  관광호텔             딘 관광호텔           김제일, 김제이
# 1225   인천광역시       중구  관광호텔             이츠관광호텔                심상우
# 1226   인천광역시       중구  관광호텔             하버파크호텔             인천관광공사
# 1227   인천광역시       중구  관광호텔            시크릿관광호텔                이재숙
# 1228   인천광역시       중구  관광호텔          아이네이버관광호텔                이승아
# ...      ...      ...   ...                ...                ...
# 1335   인천광역시       중구  관광호텔               호텔 준           이우정, 이인주
# 1336   인천광역시       중구  관광호텔           제우메스관광호텔                조용진
# 1337   인천광역시       중구  관광호텔             인천공항호텔                오형숙
# 1340   인천광역시       중구  관광호텔  네스트호텔(NEST HOTEL)               네스트㈜
# 1343   인천광역시       중구  관광호텔            파라다이스시티         ㈜파라다이스세가사미
#
#      영업상태(19.12.31기준)          주소(도로명주소)
# 1224              영업중       연안부두로43번길 12
# 1225              영업중       연안부두로53번길 15
# ...

# %%
busan_junggu = df_real[(df_real['지역1(시도)']=='부산광역시')&(df_real['지역2(시군구)']=='중구')].copy()
print("부산 중구 숙박 개수는 {}".format(len(busan_junggu)))
busan_junggu
# Out:
# 부산 중구 숙박 개수는 12
#     지역1(시도) 지역2(시군구)    업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 622   부산광역시       중구  관광호텔    (주)코모도호텔          신경록 외 1 명              영업중
# 623   부산광역시       중구  관광호텔   (주)부산관광호텔                최재원              영업중
# 624   부산광역시       중구  관광호텔     타워힐관광호텔                최용태              영업중
# 625   부산광역시       중구  관광호텔        호텔노아          이수천 외 1 명              영업중
# 626   부산광역시       중구  관광호텔    토요코인부산역Ⅱ                홍지명              영업중
# 627   부산광역시       중구  관광호텔   스탠포드 인 부산                권용범              영업중
# 628   부산광역시       중구  관광호텔  넘버25호텔 대청점                정수아              영업중
# 630   부산광역시       중구  관광호텔        반달호텔                김태광              영업중
# 631   부산광역시       중구  관광호텔       호텔 빌리                김홍빈              영업중
# 632   부산광역시       중구  관광호텔     첵앤아웃호스텔                박배웅              영업중
# 633   부산광역시       중구  관광호텔       수이호스텔                김성수              영업중
# ...

# %%
# from pandas import Series

# new_s_j = []
# for i in range(len(seoul_junggu)):
#     new_s_j.append('서울 중구')
# new_s_j = Series(data=new_s_j)
#f_real[(df_real['지역1(시도)']=='서울특별시')&(df_real['지역2(시군구)']=='중구')] = df_real[(df_real['지역1(시도)']=='서울특별시')&(df_real['지역2(시군구)']=='중구')].str.replace('중구', '서울 중구')
seoul_junggu['지역2(시군구)'] = seoul_junggu['지역2(시군구)'].str.replace('중구','서울 중구')
seoul_junggu
# Out:
#     지역1(시도) 지역2(시군구)    업종            호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 765   서울특별시    서울 중구  관광호텔                사보이호텔           (주)사보이호텔
# 766   서울특별시    서울 중구  관광호텔                메트로호텔           (주)메트로호텔
# 767   서울특별시    서울 중구  관광호텔              프레지던트호텔          백남관광 주식회사
# 768   서울특별시    서울 중구  관광호텔              서울프린스호텔         (주)서울프린스호텔
# 769   서울특별시    서울 중구  관광호텔                뉴서울호텔           (주)뉴서울호텔
# ..      ...      ...   ...                  ...                ...
# 860   서울특별시    서울 중구   호스텔               케이스타호텔        주식회사 케이스타호텔
# 861   서울특별시    서울 중구  관광호텔          나인트리 호텔 동대문        파르나스호텔 주식회사
# 862   서울특별시    서울 중구  관광호텔           호텔 미드시티 명동          아시아매니징(주)
# 863   서울특별시    서울 중구   호스텔               산마루호스텔                박한웅
# 864   서울특별시    서울 중구  관광호텔  (주)조선호텔앤리조트 포포인츠 명동        (주)조선호텔앤리조트
#
#     영업상태(19.12.31기준)                                  주소(도로명주소)
# 765              영업중                  서울특별시 중구 명동8나길 10 (충무로1가)
# ...

# %%
#df_real = df[~df['지역2(시군구)'].str.contains('군')]
incheon_junggu['지역2(시군구)'] = incheon_junggu['지역2(시군구)'].str.replace('중구','인천 중구')
incheon_junggu
# Out:
#      지역1(시도) 지역2(시군구)    업종          호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 1224   인천광역시    인천 중구  관광호텔             딘 관광호텔           김제일, 김제이
# 1225   인천광역시    인천 중구  관광호텔             이츠관광호텔                심상우
# 1226   인천광역시    인천 중구  관광호텔             하버파크호텔             인천관광공사
# 1227   인천광역시    인천 중구  관광호텔            시크릿관광호텔                이재숙
# 1228   인천광역시    인천 중구  관광호텔          아이네이버관광호텔                이승아
# ...      ...      ...   ...                ...                ...
# 1335   인천광역시    인천 중구  관광호텔               호텔 준           이우정, 이인주
# 1336   인천광역시    인천 중구  관광호텔           제우메스관광호텔                조용진
# 1337   인천광역시    인천 중구  관광호텔             인천공항호텔                오형숙
# 1340   인천광역시    인천 중구  관광호텔  네스트호텔(NEST HOTEL)               네스트㈜
# 1343   인천광역시    인천 중구  관광호텔            파라다이스시티         ㈜파라다이스세가사미
#
#      영업상태(19.12.31기준)          주소(도로명주소)
# 1224              영업중       연안부두로43번길 12
# 1225              영업중       연안부두로53번길 15
# 1226              영업중           제물량로 217
# ...

# %%
busan_junggu['지역2(시군구)'] = busan_junggu['지역2(시군구)'].str.replace('중구','부산 중구')
busan_junggu
# Out:
#     지역1(시도) 지역2(시군구)    업종   호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 622   부산광역시    부산 중구  관광호텔    (주)코모도호텔          신경록 외 1 명              영업중
# 623   부산광역시    부산 중구  관광호텔   (주)부산관광호텔                최재원              영업중
# 624   부산광역시    부산 중구  관광호텔     타워힐관광호텔                최용태              영업중
# 625   부산광역시    부산 중구  관광호텔        호텔노아          이수천 외 1 명              영업중
# 626   부산광역시    부산 중구  관광호텔    토요코인부산역Ⅱ                홍지명              영업중
# 627   부산광역시    부산 중구  관광호텔   스탠포드 인 부산                권용범              영업중
# 628   부산광역시    부산 중구  관광호텔  넘버25호텔 대청점                정수아              영업중
# 630   부산광역시    부산 중구  관광호텔        반달호텔                김태광              영업중
# 631   부산광역시    부산 중구  관광호텔       호텔 빌리                김홍빈              영업중
# 632   부산광역시    부산 중구  관광호텔     첵앤아웃호스텔                박배웅              영업중
# 633   부산광역시    부산 중구  관광호텔       수이호스텔                김성수              영업중
# ...

# %%
df_real = df_real[~df_real['지역2(시군구)'].str.contains('중구')]
df_real = pd.concat([df_real, seoul_junggu])
df_real = pd.concat([df_real, incheon_junggu])
df_real = pd.concat([df_real, busan_junggu])
df_real
# Out:
#     지역1(시도) 지역2(시군구)    업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명) 영업상태(19.12.31기준)  \
# 0        강원      춘천시  관광호텔      춘천세종관광호텔            주식회사 세종              영업중
# 1        강원      춘천시  관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠              영업중
# 2        강원      원주시  관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주              영업중
# 4        강원      원주시  관광호텔         호텔비즈인            주식회사 청연              영업중
# 5        강원      원주시  관광호텔        ㈜오키드호텔          주식회사오키드호텔              영업중
# ..      ...      ...   ...           ...                ...              ...
# 630   부산광역시    부산 중구  관광호텔          반달호텔                김태광              영업중
# 631   부산광역시    부산 중구  관광호텔         호텔 빌리                김홍빈              영업중
# 632   부산광역시    부산 중구  관광호텔       첵앤아웃호스텔                박배웅              영업중
# 633   부산광역시    부산 중구  관광호텔         수이호스텔                김성수              영업중
# 634   부산광역시    부산 중구  관광호텔       브로시스 호텔                성락식              영업중
#
#                            주소(도로명주소)
# ...

# %%
df_real = df_real.reset_index()
df_real
# Out:
#       level_0  index 지역1(시도) 지역2(시군구)    업종     호텔명(등록명칭) 관광사업자명(법인명 or 개인명)  \
# 0           0      0      강원      춘천시  관광호텔      춘천세종관광호텔            주식회사 세종
# 1           1      1      강원      춘천시  관광호텔     춘천베어스관광호텔       유한회사 화성에이에스엠
# 2           2      2      강원      원주시  관광호텔  (주)호텔인터불고 원주        (주)호텔인터불고원주
# 3           3      4      강원      원주시  관광호텔         호텔비즈인            주식회사 청연
# 4           4      5      강원      원주시  관광호텔        ㈜오키드호텔          주식회사오키드호텔
# ...       ...    ...     ...      ...   ...           ...                ...
# 1938     1938    630   부산광역시    부산 중구  관광호텔          반달호텔                김태광
# 1939     1939    631   부산광역시    부산 중구  관광호텔         호텔 빌리                김홍빈
# 1940     1940    632   부산광역시    부산 중구  관광호텔       첵앤아웃호스텔                박배웅
# 1941     1941    633   부산광역시    부산 중구  관광호텔         수이호스텔                김성수
# 1942     1942    634   부산광역시    부산 중구  관광호텔       브로시스 호텔                성락식
#
# ...

# %%
df_real['지역2(시군구)'].value_counts().head(15)
# Out:
# 서귀포시     208
# 제주시      201
# 여수시      185
# 인천 중구    111
# 서울 중구    100
# 강남구       69
# 순천시       63
# 수영구       60
# 해운대구      59
# 종로구       39
# 수원시       37
# 영등포구      33
# 통영시       31
# 동구        26
# 창원시       25
# Name: 지역2(시군구), dtype: int64

# %%
df_real['지역2(시군구)'].value_counts().tail(15)
# Out:
# 김천시     1
# 당진시     1
# 노원구     1
# 오산시     1
# 서산시     1
# 하남시     1
# 양주시     1
# 부평구     1
# 경산시     1
# 상주시     1
# 영도구     1
# 미추홀구    1
# 양천구     1
# 사상구     1
# 영천시     1
# Name: 지역2(시군구), dtype: int64
